# %% [markdown]
# <a href="https://colab.research.google.com/github/Yogesh914/first_steps_into_ai_workshop_code/blob/main/workshop_lab_activity.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt

# %%
# Load the MNIST dataset
# Let's incorporate the widely-used MNIST dataset, which consists of handwritten digit images.

transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5,), (0.5,))])

train_set = torchvision.datasets.MNIST(root='./data', train=True, download=True, transform=transform)
train_loader = torch.utils.data.DataLoader(train_set, batch_size=64, shuffle=True, num_workers=2)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to ./data/MNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 9912422/9912422 [00:00<00:00, 121735840.66it/s]
# Extracting ./data/MNIST/raw/train-images-idx3-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to ./data/MNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 28881/28881 [00:00<00:00, 31777464.28it/s]
# Extracting ./data/MNIST/raw/train-labels-idx1-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 1648877/1648877 [00:00<00:00, 33526067.93it/s]
# Extracting ./data/MNIST/raw/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 4542/4542 [00:00<00:00, 23813160.96it/s]
# Extracting ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw

# %%
# Define the neural network
class SimpleNet(nn.Module):
    def __init__(self):
        super(SimpleNet, self).__init__()
        self.fc1 = nn.Linear(28 * 28, 64)
        self.fc2 = nn.Linear(64, 10)

    def forward(self, x):
        x = x.view(-1, 28 * 28)
        x = torch.relu(self.fc1(x))
        x = self.fc2(x)
        return x

net = SimpleNet()

# %%
# Set loss function and optimizer
criterion = nn.CrossEntropyLoss()

# Modify this value to experiment with different learning rates
learning_rate = 0.1

optimizer = optim.SGD(net.parameters(), lr=learning_rate, momentum=0.9)

# %%
# Modify the num_epochs number and see what happens
num_epochs = 10
loss_history = []

# Get some random training images
dataiter = iter(train_loader)
images, labels = next(dataiter)

# %%
# Function to show an image
def imshow(img):
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()

# Show images
imshow(torchvision.utils.make_grid(images))

# %%
for epoch in range(num_epochs):
    running_loss = 0.0
    for i, data in enumerate(train_loader, 0):
        inputs, labels = data
        optimizer.zero_grad()
        outputs = net(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()

        # Print the first 4 predicted labels of the first batch in each epoch
        if i == 0:
            _, predicted = torch.max(outputs, 1)
            print('First batch of epoch: ', epoch)
            print('GroundTruth: ', ' '.join('%5s' % labels[j].item() for j in range(4)))
            print('Predicted: ', ' '.join('%5s' % predicted[j].item() for j in range(4)))
            imshow(torchvision.utils.make_grid(inputs[:4]))

    epoch_loss = running_loss / (i + 1)
    loss_history.append(epoch_loss)
    print(f"Epoch {epoch + 1}, Loss: {epoch_loss}")
# Out:
# First batch of epoch:  0
# GroundTruth:      1     3     0     0
# Predicted:      5     5     8     0
# Epoch 1, Loss: 1.4385802661305043
# First batch of epoch:  1
# GroundTruth:      0     9     9     6
# Predicted:      0     1     1     6
# Epoch 2, Loss: 1.416641922647765
# First batch of epoch:  2
# GroundTruth:      4     4     9     7
# Predicted:      4     4     9     9
# Epoch 3, Loss: 1.5581214635738179
# First batch of epoch:  3
# GroundTruth:      9     7     4     5
# Predicted:      9     7     9     9
# Epoch 4, Loss: 1.4211067340648504
# First batch of epoch:  4
# GroundTruth:      7     4     6     7
# Predicted:      7     1     6     7
# Epoch 5, Loss: 1.57114054246752
# First batch of epoch:  5
# GroundTruth:      8     4     3     6
# Predicted:      2     2     2     6
# Epoch 6, Loss: 1.578326498267493
# First batch of epoch:  6
# GroundTruth:      9     1     7     7
# Predicted:      9     9     7     7
# Epoch 7, Loss: 1.5840774168337841
# First batch of epoch:  7
# GroundTruth:      8     9     9     1
# Predicted:      1     1     7     1
# Epoch 8, Loss: 1.561469065609263
# First batch of epoch:  8
# GroundTruth:      2     6     5     9
# Predicted:      4     6     4     4
# Epoch 9, Loss: 1.6522192963913305
# First batch of epoch:  9
# GroundTruth:      8     1     4     3
# Predicted:      2     2     2     2
# Epoch 10, Loss: 2.00494533561186

# %%
# Visualize the training loss
plt.plot(loss_history)
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title(f'Training Loss (Learning Rate: {learning_rate})')
plt.show()
